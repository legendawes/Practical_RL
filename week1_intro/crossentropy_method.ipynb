# %% [markdown]
# # Crossentropy method
#
# This notebook will teach you to solve reinforcement learning problems with crossentropy method. We'll follow-up by scaling everything up and using neural network policy.

# %%
#XVFB will be launched if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
import gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v2")
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print("n_states=%i, n_actions=%i"%(n_states,n_actions))
# Out:
# n_states=500, n_actions=6

# %% [markdown]
# Количество n_states и n_actions маленькое, поэтому используем матрицу, а не нейросеть

# %% [markdown]
# # Create stochastic policy
#
# This time our policy should be a probability distribution.
#
# ```policy[s,a] = P(take action a | in state s)```
#
# Since we still use integer state and action representations, you can use a 2-dimensional array to represent the policy.
#
# Please initialize policy __uniformly__, that is, probabililities of all actions should be equal.

# %%
policy = np.ones((n_states, n_actions)) / n_actions

# %%
assert type(policy) in (np.ndarray,np.matrix)
assert np.allclose(policy,1./n_actions)
assert np.allclose(np.sum(policy,axis=1), 1)

# %%
env = gym.make("Taxi-v2")
env.reset()

n_states = env.observation_space.n
n_actions = env.action_space.n

policy = np.ones((n_states, n_actions)) / n_actions

# %% [markdown]
# # Play the game
#
# Just like before, but we also record all states and actions we took.

# %%
def generate_session_with_policy(policy,t_max=10**4):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states,actions = [],[]
    total_reward = 0.
    
    s = env.reset()
    
    for t in range(t_max):
        
#         a = <sample action from policy (hint: use np.random.choice)>
        a = np.random.choice(list(range(n_actions)), p=policy[s])
        
        new_s,r,done,info = env.step(a)
        
        #Record state, action and add up reward to states,actions and total_reward accordingly.
        # We need to add rewards in order to choose sessions with biggest rewards
        states.append(s)
        actions.append(a)
        total_reward+=r
        
        s = new_s
        if done:
            break
    return states,actions,total_reward

# %%
s,a,r = generate_session_with_policy(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float,np.float]

# %%
#let's see the initial reward distribution
import matplotlib.pyplot as plt
# %matplotlib inline

sample_rewards = [generate_session_with_policy(policy,t_max=1000)[-1] for _ in range(200)]

plt.hist(sample_rewards,bins=20);
plt.vlines([np.percentile(sample_rewards,50)],[0],[100],label="50'th percentile",color='green')
plt.vlines([np.percentile(sample_rewards,90)],[0],[100],label="90'th percentile",color='red')
plt.legend()

# %% [markdown]
# We can choose 50'th percentile and get a lot of games, but quality will be poor. Better generate more games and choose 90'th percentile. Or some else percentile, depends on amount of games.

# %% [markdown]
# ### Crossentropy method steps (2pts)

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """
    
#     reward_threshold = <Compute minimum reward for elite sessions. Hint: use np.percentile>
    reward_threshold = np.percentile(rewards_batch, percentile)
    
    elite_states  = np.array(states_batch)[np.array(rewards_batch) >= reward_threshold]
    elite_actions = np.array(actions_batch)[np.array(rewards_batch) >= reward_threshold]
    
    elite_states = [item for sublist in elite_states for item in sublist]
    elite_actions = [item for sublist in elite_actions for item in sublist]
    
    return elite_states,elite_actions

# %%
states_batch = [
    [1,2,3],   #game1
    [4,2,0,2], #game2
    [3,1]      #game3
]

actions_batch = [
    [0,2,4],   #game1
    [3,2,0,1], #game2
    [3,3]      #game3
]
rewards_batch = [
    3,         #game1
    4,         #game2
    5,         #game3
]

test_result_0 = select_elites(states_batch,actions_batch,rewards_batch,percentile=0)
test_result_40 = select_elites(states_batch,actions_batch,rewards_batch,percentile=30)
test_result_90 = select_elites(states_batch,actions_batch,rewards_batch,percentile=90)
test_result_100 = select_elites(states_batch,actions_batch,rewards_batch,percentile=100)

assert np.all(test_result_0[0] == [1, 2, 3, 4, 2, 0, 2, 3, 1])  \
   and np.all(test_result_0[1] == [0, 2, 4, 3, 2, 0, 1, 3, 3]),\
        "For percentile 0 you should return all states and actions in chronological order"
assert np.all(test_result_40[0] == [4, 2, 0, 2, 3, 1]) and \
        np.all(test_result_40[1] ==[3, 2, 0, 1, 3, 3]),\
        "For percentile 30 you should only select states/actions from two first"
assert np.all(test_result_90[0] == [3,1]) and \
        np.all(test_result_90[1] == [3,3]),\
        "For percentile 90 you should only select states/actions from one game"
assert np.all(test_result_100[0] == [3,1]) and\
       np.all(test_result_100[1] == [3,3]),\
        "Please make sure you use >=, not >. Also double-check how you compute percentile."
print("Ok!")
# Out:
# Ok!

# %%
def update_policy(elite_states,elite_actions):
    """
    Given old policy and a list of elite states/actions from select_elites,
    return new updated policy where each action probability is proportional to
    
    policy[s_i,a_i] ~ #[occurences of si and ai in elite states/actions]
    
    Don't forget to normalize policy to get valid probabilities and handle 0/0 case.
    In case you never visited a state, set probabilities for all actions to 1./n_actions
    
    :param elite_states: 1D list of states from elite sessions
    :param elite_actions: 1D list of actions from elite sessions
    
    """
    
    new_policy = np.zeros([n_states,n_actions])
    
#     <Your code here: update probabilities for actions given elite states & actions>
    #Don't forget to set 1/n_actions for all actions in unvisited states.
    
    not_visited = np.ones(n_states, dtype=bool)
    for state, action in zip(elite_states, elite_actions):
        new_policy[state][action] += 1
        not_visited[state] = False
    
    new_policy[not_visited] = 1
    
    row_sum = new_policy.sum(axis=1).reshape([n_states,1])
    new_policy = np.divide(new_policy, row_sum)
                           
    return new_policy

# %%
elite_states, elite_actions = ([1, 2, 3, 4, 2, 0, 2, 3, 1], [0, 2, 4, 3, 2, 0, 1, 3, 3])


new_policy = update_policy(elite_states,elite_actions)

assert np.isfinite(new_policy).all(), "Your new policy contains NaNs or +-inf. Make sure you don't divide by zero."
assert np.all(new_policy>=0), "Your new policy can't have negative action probabilities"
assert np.allclose(new_policy.sum(axis=-1),1), "Your new policy should be a valid probability distribution over actions"
reference_answer = np.array([
       [ 1.        ,  0.        ,  0.        ,  0.        ,  0.        ],
       [ 0.5       ,  0.        ,  0.        ,  0.5       ,  0.        ],
       [ 0.        ,  0.33333333,  0.66666667,  0.        ,  0.        ],
       [ 0.        ,  0.        ,  0.        ,  0.5       ,  0.5       ]])
assert np.allclose(new_policy[:4,:5],reference_answer)
print("Ok!")
# Out:
# Ok!

# %% [markdown]
# # Training loop
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output

def show_progress(rewards_batch, log, percentile, reward_range=[-990,+10]):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """
    
    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch,percentile)
    log.append([mean_reward,threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f"%(mean_reward,threshold))
    plt.figure(figsize=[8,4])
    plt.subplot(1,2,1)
    plt.plot(list(zip(*log))[0],label='Mean rewards')
    plt.plot(list(zip(*log))[1],label='Reward thresholds')
    plt.legend()
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.hist(rewards_batch,range=reward_range);
    plt.vlines([np.percentile(rewards_batch,percentile)],[0],[100],label="percentile",color='red')
    plt.legend()
    plt.grid()

    plt.show()

# %%
#reset policy just in case
policy = np.ones([n_states,n_actions])/n_actions

# %%
n_sessions = 250  #sample this many sessions
percentile = 50  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

log = []

for i in range(100):
    
    # %time sessions = [generate_session_with_policy(policy) for j in range(n_sessions)]
    
    states_batch,actions_batch,rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch,
                                                percentile=percentile)
    
    new_policy = update_policy(elite_states, elite_actions)
    
    policy = learning_rate*new_policy + (1-learning_rate)*policy
    
    #display results on chart
    show_progress(rewards_batch,log,percentile)
# Out:
# mean reward = -47.612, threshold=7.000

# %% [markdown]
# В элитных траекториях могут оказаться те, когда нам просто везёт (например, в одноруком бандите элитными всегда будут траектории, когда мы выиграли). У такси положение меняется и мы не умеем правильно обрабатывать четверть, но они никогда не оказываются в элитных и кроссэнтропия забивает.
#
# Уменьшение персентиили и увеличение количества игр поможет, но не панацея.
#
# Засэмплировать для каждого состояния по одному действию. Вместо того, чтобы играть один раз с этим действиями, играем 10 игр с фиксированной политикой и усредняем. В случае с автоматом: постоянно играем или постоянно отходим.
# Заранее случайно выбираем действие, которое делаем в состоянии.
#
# Вторая проблема - состояний может быть очень много.

# %% [markdown]
# # Digging deeper: approximate crossentropy with neural nets
#
# ![img](https://casd35.wikispaces.com/file/view/digging_deeper_final.jpg/359658499/503x260/digging_deeper_final.jpg)
#
# In this section we will train a neural network policy for continuous state space game

# %% [markdown]
# Задача тележки - удержать палку на маятнике

# %%
env = gym.make("CartPole-v0").env  #if you see "<classname> has no attribute .env", remove .env or update gym

env.reset()
n_actions = env.action_space.n

plt.imshow(env.render("rgb_array"))
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
env.reset()
# Out:
# array([ 0.02521612, -0.01062285,  0.04328544,  0.035677  ])

# %%
#create agent
from sklearn.neural_network import MLPClassifier
agent = MLPClassifier(hidden_layer_sizes=(20,20),
                      activation='tanh',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=1 #make only 1 iteration on each .fit(...)
                     )
#initialize agent to the dimension of state an amount of actions
agent.fit([env.reset()]*n_actions,range(n_actions));
# Out:
# /home/awesome/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# Получить вероятность действий для состояния можно просто:

# %%
agent.predict_proba([env.reset()])[0]
# Out:
# array([0.5011406, 0.4988594])

# %%
def generate_session(t_max=1000):
    
    states,actions = [],[]
    total_reward = 0
    
    s = env.reset()
    
    for t in range(t_max):
        
        #predict array of action probabilities
        probs = agent.predict_proba([s])[0]
        
        a = np.random.choice(list(range(n_actions)), p=probs)
        
        new_s,r,done,info = env.step(a)
        
        #record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward+=r
        
        s = new_s
        if done: break
    return states,actions,total_reward

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    #generate new sessions
    sessions = [generate_session() for j in range(n_sessions)]

    states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch,
                                                percentile=percentile)
    
#     <fit agent to predict elite_actions(y) from elite_states(X)>
    agent.fit(elite_states, elite_actions)

    show_progress(rewards_batch,log,reward_range=[0,np.max(rewards_batch)],percentile=percentile)
    
    if np.mean(rewards_batch)> 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
# Out:
# mean reward = 314.630, threshold=383.600
# You Win! You may stop training now via KeyboardInterrupt.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-fcd6e83f0108> in <module>()
#       5 for i in range(100):
#       6     #generate new sessions
# ----> 7     sessions = [generate_session() for j in range(n_sessions)]
#       8
#       9     states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))
#
# <ipython-input-23-fcd6e83f0108> in <listcomp>(.0)
#       5 for i in range(100):
#       6     #generate new sessions
# ----> 7     sessions = [generate_session() for j in range(n_sessions)]
#       8
#       9     states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))
#
# <ipython-input-21-802978f02b37> in generate_session(t_max)
#      11         probs = agent.predict_proba([s])[0]
#      12
# ...

# %% [markdown]
# # Results

# %%
#record sessions
import gym.wrappers
env = gym.wrappers.Monitor(gym.make("CartPole-v0"),directory="videos",force=True)
sessions = [generate_session() for _ in range(100)]
env.close()
#upload to gym
#gym.upload("./videos/",api_key="<your_api_key>") #you'll need me later
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
#show video
from IPython.display import HTML
import os

video_names = list(filter(lambda s:s.endswith(".mp4"),os.listdir("./videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./videos/"+video_names[-1])) #this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./videos/openaigym.video.0.2477.video000000.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework part I
#
# ### Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (1 pts) Find out how the algorithm performance changes if you change different percentile and different n_samples.
# - __1.2__ (2 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %% [markdown]
# ```<Describe what you did here.  Preferably with plot/report to support it.>```

# %% [markdown]
# __1.1__ (1 pts) Find out how the algorithm performance changes if you change different percentile and different n_samples.

# %% [markdown]
# #### Initialize

# %%
env = gym.make("Taxi-v2")
env.reset()

n_states = env.observation_space.n
n_actions = env.action_space.n

# %%
def train_tabular_crossentropy(n_sessions=250, percentile=50, learning_rate=0.5, n_iter=100,
                               return_data=False):
    env.reset()
    policy = np.ones((n_states, n_actions)) / n_actions
    log = []

    for i in range(n_iter):
        sessions = [generate_session_with_policy(policy) for j in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = zip(*sessions)
        
        elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch,
                                                    percentile=percentile)

        new_policy = update_policy(elite_states, elite_actions)

        policy = learning_rate*new_policy + (1-learning_rate)*policy

        #display results on chart
        show_progress(rewards_batch,log,percentile)
    if return_data: return sessions, log

# %% [markdown]
# * Посмотрим на результаты при изменении значений персентили. Идейно меньшее значение персентили должно приводить к меньшей скорости сходимости (так как выбираем не самые лучшие) и большей стабильности mean rewards, так как при обучении учитывается большее количество ситуаций.

# %%
train_tabular_crossentropy(percentile=20)
# Out:
# mean reward = -93.668, threshold=-200.000

# %%
train_tabular_crossentropy(percentile=30)
# Out:
# mean reward = -4.696, threshold=4.000

# %%
train_tabular_crossentropy(percentile=40)
# Out:
# mean reward = -12.492, threshold=6.000

# %%
train_tabular_crossentropy(percentile=50)
# Out:
# mean reward = -105.608, threshold=6.000

# %%
train_tabular_crossentropy(percentile=60)
# Out:
# mean reward = -174.692, threshold=8.000

# %%
train_tabular_crossentropy(percentile=70)
# Out:
# mean reward = -265.460, threshold=2.600

# %%
train_tabular_crossentropy(percentile=80)
# Out:
# mean reward = -397.832, threshold=8.000

# %%
train_tabular_crossentropy(percentile=90)
# Out:
# mean reward = -557.012, threshold=10.000

# %% [markdown]
# Видим, что уменьшение персентили действительно замедляет первоначально быструю сходимость, а при 20й персентили сходимость прекращается. 30я и 40я при этом показывают результат лучше дефолтной 50й персентили. Видимо, на них достигается баланс между качеством elite_sessions и количеством получаемой обучающей выборки.

# %% [markdown]
# * Перейдем к рассмотрению влияния n_sessions при фиксированной персентили. Увеличение n_sessions приводит к обучению на большем числе примеров, поэтому reward должен расти вместе с n_sessions.

# %%
train_tabular_crossentropy(n_sessions=300)
# Out:
# mean reward = -42.410, threshold=7.000

# %%
train_tabular_crossentropy(n_sessions=400)
# Out:
# mean reward = -46.958, threshold=8.000

# %%
train_tabular_crossentropy(n_sessions=500)
# Out:
# mean reward = -45.068, threshold=8.000

# %%
train_tabular_crossentropy(n_sessions=700)
# Out:
# mean reward = -40.016, threshold=8.000

# %% [markdown]
# Увеличение n_sessions не привело к увеличению средней награды, так как всё ещё наблюдается расходимость. Персентили 30 и 40, судя по эксперименту с персентилями, должны исправить эту расходимость. Проверим, поможет ли одновременный тюнинг добиться положительного mean reward.

# %% [markdown]
# __1.2__ (2 pts) Tune the algorithm to end up with positive average score.

# %%
train_tabular_crossentropy(percentile=30, n_sessions=500)
# Out:
# mean reward = -15.554, threshold=6.000

# %%
train_tabular_crossentropy(percentile=25, n_sessions=1200)
# Out:
# mean reward = -4.518, threshold=7.000

# %%
train_tabular_crossentropy(percentile=20, n_sessions=1500)
# Out:
# mean reward = 2.964, threshold=6.000

# %% [markdown]
# #### Bingo!

# %% [markdown]
# # Homework part II
#
# ### Deep crossentropy method
#
# By this moment you should have got enough score on [CartPole-v0](https://gym.openai.com/envs/CartPole-v0) to consider it solved (see the link). It's time to upload the result and get to something harder.
#
# * if you have any trouble with CartPole-v0 and feel stuck, feel free to ask us or your peers for help.
#
# ### Tasks
#
# * __2.1__ (3 pts) Pick one of environments: MountainCar-v0 or LunarLander-v2.
#   * For MountainCar, get average reward of __at least -150__
#   * For LunarLander, get average reward of __at least +50__
#   * For any environment, upload it to gym and post url in your anytask form.
#
# See the tips section below, it's kinda important.
# __Note:__ If your agent is below the target score, you'll still get most of the points depending on the result, so don't be afraid to submit it.
#
#
# * __2.2__ (bonus: 4++ pt) Devise a way to speed up training at least 2x against the default version
#   * Obvious improvement: use [joblib](https://www.google.com/search?client=ubuntu&channel=fs&q=joblib&ie=utf-8&oe=utf-8)
#   * Try re-using samples from 3-5 last iterations when computing threshold and training
#   * Experiment with amount of training iterations and learning rate of the neural network (see params)
#   * __Please list what you did in anytask submission form__
#
#
# ### Tips
# * Gym page: [mountaincar](https://gym.openai.com/envs/MountainCar-v0), [lunarlander](https://gym.openai.com/envs/LunarLander-v2)
# * Sessions for MountainCar may last for 10k+ ticks. Make sure ```t_max``` param is at least 10k.
#  * Also it may be a good idea to cut rewards via ">" and not ">=". If 90% of your sessions get reward of -10k and 20% are better, than if you use percentile 20% as threshold, R >= threshold __fails cut off bad sessions__ whule R > threshold works alright.
# * _issue with gym_: Some versions of gym limit game time by 200 ticks. This will prevent cem training in most cases. Make sure your agent is able to play for the specified __t_max__, and if it isn't, try `env = gym.make("MountainCar-v0").env` or otherwise get rid of TimeLimit wrapper.
# * If you use old _swig_ lib for LunarLander-v2, you may get an error. See this [issue](https://github.com/openai/gym/issues/100) for solution.
# * If it won't train it's a good idea to plot reward distribution and record sessions: they may give you some clue. If they don't, call course staff :)
# * 20-neuron network is probably not enough, feel free to experiment.
# * __Please upload the results to openai gym and send links to all submissions in the e-mail__

# %% [markdown]
# __2.1__ (3 pts) For MountainCar, get average reward of __at least -150__

# %%
from sklearn.neural_network import MLPClassifier

# %%
env = gym.make("MountainCar-v0").env
env.reset()
n_actions = env.action_space.n
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """
    
    reward_threshold = np.percentile(rewards_batch, percentile)
    
    elite_states  = np.array(states_batch)[np.array(rewards_batch) > reward_threshold]
    elite_actions = np.array(actions_batch)[np.array(rewards_batch) > reward_threshold]
    
    elite_states = [item for sublist in elite_states for item in sublist]
    elite_actions = [item for sublist in elite_actions for item in sublist]
    
    return elite_states,elite_actions

# %%
def generate_session(t_max=1000):
    
    states,actions = [],[]
    total_reward = 0
    
    s = env.reset()
    
    for t in range(t_max):
        
        #predict array of action probabilities
        probs = agent.predict_proba([s])[0]
        
        a = np.random.choice(list(range(n_actions)), p=probs)
        
        new_s,r,done,info = env.step(a)
        
        #record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r
        
        s = new_s
        if done: break
    return states,actions,total_reward

# %%
agent = MLPClassifier(hidden_layer_sizes=(20,20),
                      activation='tanh',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=1 #make only 1 iteration on each .fit(...)
                     )

# %%
def train_deep_crossentropy(agent, n_sessions=100, percentile=70, progress=True, return_last_mean=False,
                           target_value=-150):
    agent.fit([env.reset()]*n_actions,range(n_actions))
    log = []

    for i in range(100):
        sessions = [generate_session(10000) for j in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))

        elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch,
                                                    percentile=percentile)

        if len(elite_states) == 0:
            print('no elites found')
            continue
        agent.fit(elite_states, elite_actions)
        
        if progress:
            show_progress(rewards_batch,log,reward_range=[-10000,np.max(rewards_batch)],percentile=percentile)

        if np.mean(rewards_batch)> target_value:
            print("You Win!")
            break
    if return_last_mean:
        return np.mean(rewards_batch)

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Попробуем увеличить максимальное количество итераций

# %%
agent = MLPClassifier(hidden_layer_sizes=(20,20),
                      activation='tanh',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=2 #make only 1 iteration on each .fit(...)
                     )

# %%
train_deep_crossentropy(agent, progress=True, return_last_mean=False, target_value=-150)
# Out:
# mean reward = -9053.600, threshold=-10000.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-0c57db2fb9df> in <module>()
# ----> 1 train_deep_crossentropy(agent, progress=True, return_last_mean=False, target_value=-150)
#
# <ipython-input-44-daf8f62ae3bb> in train_deep_crossentropy(agent, n_sessions, percentile, progress, return_last_mean, target_value)
#       5
#       6     for i in range(100):
# ----> 7         sessions = [generate_session(10000) for j in range(n_sessions)]
#       8
#       9         states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))
#
# <ipython-input-44-daf8f62ae3bb> in <listcomp>(.0)
#       5
#       6     for i in range(100):
# ----> 7         sessions = [generate_session(10000) for j in range(n_sessions)]
#       8
#       9         states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))
#
# ...

# %% [markdown]
# Другая функция активации:

# %%
agent = MLPClassifier(hidden_layer_sizes=(20,20),
                      activation='relu',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=1 #make only 1 iteration on each .fit(...)
                     )

train_deep_crossentropy(agent, progress=True, return_last_mean=False, target_value=-150)

# %% [markdown]
# Больше нейронов

# %%
agent = MLPClassifier(hidden_layer_sizes=(30,30),
                      activation='tanh',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=1 #make only 1 iteration on each .fit(...)
                     )

train_deep_crossentropy(agent, progress=True, return_last_mean=False, target_value=-150)

# %%
res = []
for hidden_layers in [(20,20), (30,30), (40,40)]:
    for activation in ['tanh', 'relu']:
        for learning_rate_init in [0.001, 0.0001, 0.01]:
            for max_iter in [1,2,5]:
                agent = MLPClassifier(hidden_layer_sizes=hidden_layers,
                              activation=activation,
                              warm_start=True, learning_rate_init=learning_rate_init,
                              max_iter=max_iter
                             )
                try:
                    mean = train_deep_crossentropy(agent, progress=False, return_last_mean=True)

                    res.append(mean, agent)
                    print(agent, mean)
                except:
                    print('FAILED', agent)
# Out:
# no elites found
# no elites found
# FAILED MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)
# You Win! You may stop training now via KeyboardInterrupt.
# You Win! You may stop training now via KeyboardInterrupt.
# You Win! You may stop training now via KeyboardInterrupt.
# You Win! You may stop training now via KeyboardInterrupt.
# FAILED MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='constant',
# ...

# %%
n_sessions=100
percentile=70
log = []

for i in range(100):
    sessions = [generate_session(10000) for j in range(n_sessions)]

    states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch,
                                                percentile=percentile)
    if len(elite_states) == 0:
        print('no elites found')
        continue
    agent.fit(elite_states, elite_actions)

    show_progress(rewards_batch,log,reward_range=[-7000,
                                                  np.max(rewards_batch)],percentile=percentile)
    
    if np.mean(rewards_batch)> -150:
        print("You Win! You may stop training now via KeyboardInterrupt.")
# Out:
# mean reward = -159.890, threshold=-139.000

# %% [markdown]
# __2.2__ (bonus: 4++ pt) Devise a way to speed up training at least 2x against the default version
#   * Obvious improvement: use [joblib](https://www.google.com/search?client=ubuntu&channel=fs&q=joblib&ie=utf-8&oe=utf-8)
#   * Try re-using samples from 3-5 last iterations when computing threshold and training
#   * Experiment with amount of training iterations and learning rate of the neural network (see params)
#   * __Please list what you did in anytask submission form__

# %% [markdown]
# ### Bonus tasks
#
# * __2.3 bonus__ Try to find a network architecture and training params that solve __both__ environments above (_Points depend on implementation. If you attempted this task, please mention it in anytask submission._)
#
# * __2.4 bonus__ Solve continuous action space task with `MLPRegressor` or similar.
#   * [MountainCarContinuous-v0](https://gym.openai.com/envs/MountainCarContinuous-v0), [LunarLanderContinuous-v2](https://gym.openai.com/envs/LunarLanderContinuous-v2)
#   * 4 points for solving. Slightly less for getting some results below solution threshold. Note that discrete and continuous environments may have slightly different rules aside from action spaces.
#
#
# If you're still feeling unchallenged, consider the project (see other notebook in this folder).
